# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("demo").master("local[*]").getOrCreate()
sdf = spark.createDataFrame([(1, "a"), (2, "b")], ["id", "name"])
pdf = sdf.toPandas()   # pandas.DataFrame
print(type(pdf))       # <class 'pandas.core.frame.DataFrame'>
print(pdf)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/20 01:32:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 0:>                                                        (0 + 12) / 12]
# <class 'pandas.core.frame.DataFrame'>
#    id name
# 0   1    a
# 1   2    b
