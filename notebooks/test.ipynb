# %% [markdown]
# дан отсортированный массив nums и число target. Нужно найти два элемента, сумма которых равна target.

# %%
nums = [1,2,3,3]
for i in nums:
    if (nums.count(i) > 1):
        print(True)
        break;
# Out:
# True

# %%
nums = [ 1, 2, 3, 4, 5]
target = 7

# %%
for i in range(0,len(nums)):
    for j in range(i+1,len(nums)):
        if nums[i] + nums[j] == target:
            print(nums[i], nums[j])
            break
# Out:
# 2 5
# 3 4

# %%
for i in nums:
    nums.find()

# %% [markdown]
# Дана строка s.
# Нужно вернуть первый символ, который встречается только один раз.
# Если такого символа нет — вернуть None

# %%
s = "abaccabadd"
triger = False
for i in s:
    if s.count(i) == 1:
        print(i)
        triger = True
        break
if triger == False:
    print(None)
# Out:
# None
